# %%
#Aggiungere alla classe Node le funzioni add_left(v) e add_right(v) che aggiungono il nodo v rispettiamente come figlio sinistro e destro 
#al nodo su cui vengono invocate. Se un figlio in quella posizione fosse già presente lo sostituiscono.

class Node:
    
    def __init__(self, data=None, left=None, right=None):
        self._data = data
        self._left = left
        self._right = right
        
    def __str__(self):
        s = "(" + str(self._data) + ", "
        if not self._left == None:
            s += self._left.__str__()
        s += ", "
        if not self._right == None:
            s += self._right.__str__()
        return s + ")"
        
    def add_left(self, v):
        self._left = v
        
    def add_right(self, v):
        self._right = v

# %%
#Implementare nella classe Node un metodo onlyLeft() che restituisce True se tutti i nodi dell'albero binario radicato nel nodo su cui si chiama la funzione
#hanno solamente il figlio sinistro o non hanno nessun figlio.


class Node:
    def __init__(self, data=None, left=None, right=None):
        self._data = data
        self._left = left
        self._right = right
        
        
    def onlyLeft(self):
        if self._right is not None :
            return False
        if self._left is not None :
            return self._left.onlyLeft()
        return True

# %%
#Modificare le funzioni addLeft(v) e addRight(v) scritte in precedenza di modo che se il figlio fosse già presente,
# il nuovo nodo viene aggiunto come prima foglia a sinistra o ultima foglia a destra, rispettivamente.

#Suggerimenti:

#E' simile ad inserire un nodo nella prima o ultima posizione di un albero binario di ricerca


class Node:
    def __init__(self, data=None, left=None, right=None):
        self._data = data
        self._left = left
        self._right = right
    def __str__(self):
        s = "(" + str(self._data) + ", "
        if not self._left == None:
            s += self._left.__str__()
        s += ", "
        if not self._right == None:
            s += self._right.__str__()
        return s + ")"
        
    def addLeft(self, v):
        if self._left is None :
            self._left = v
        else:
            self._left.addLeft(v)
            
    def addRight(self, v):
        if self._right is None :
            self._right = v
        else:
            self._right.addRight(v)

# %%
#Implementare nella classe Node la funzione search(n) che cerca nell'albero binario un nodo il cui l'attributo _data sia uguale a n 
#e di conseguenza restituisca True se lo trova oppure False.



class Node:
    
    def __init__(self, data=None, left=None, right=None):
        self._data = data
        self._left = left
        self._right = right

    def search(self, n):
        if self._data == n:
            return True 
        else:
            found = False
            if self._left is not None:
                found = self._left.search(n)
            if not found and self._right is not None :
                found = self._right.search(n)
        return found

# %%
#Definire nella classe Node una funzione count_nodes() che calcola e restituisce il numero di nodi nel sottoalbero radicato al nodo su cui la funzione viene invocata.

#Suggerimento: provare ad usare la ricorsione.


class Node:
    
    def __init__(self, data=None, left=None, right=None):
        self._data = data
        self._left = left
        self._right = right
        
    def count_nodes(self):
        count = 1
        if self._left is not None :
            count += self._left.count_nodes()
        if self._right is not None :
            count += self._right.count_nodes()
        return count
